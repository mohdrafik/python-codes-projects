# %%
import os 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

list_files = os.listdir()
list_files
# hamaker = []
count = 0
val = [0]
val = pd.DataFrame(val)
col_size_total = 0


for files in list_files:
    count = count +1
    df = pd.read_excel(files)
    hamaker_data  = df['hamaker_values']
    col_size = hamaker_data.shape[0]
    col_size_total = col_size_total + col_size

    val = pd.concat([val,hamaker_data],axis=0,ignore_index= True)
    # print("count and size of the hamaker and val size --> :", count,val.shape,col_size,col_size_total)

    # hamaker = val[1:]   
    # print("length of hamaker :",len(hamaker))
    # plt.figure
    # plt.hist(hamaker)   
    # # plt.scatter(df['piezo_meter'],df['hamaker_values'],s=2)
    # plt.ylabel('Counts')
    # plt.xlabel('Hamaker Constant')
    # plt.title('Histogram hamaker')


hamaker = val[1:]   
print("length of hamaker :",len(hamaker))
plt.figure
plt.hist(hamaker,color= 'magenta',alpha = 0.5)   
# plt.scatter(df['piezo_meter'],df['hamaker_values'],s=2)
plt.ylabel('Counts')
plt.xlabel('Hamaker Constant')
# plt.xlim([0, 5e-10])
# plt.xticks([0,5e-10,10e-9,15e-9,20e-9,25e-9,30e-9,35e-9])
# plt.xticks([0,5e-11,10e-11,15e-11,20e-11,25e-11,30e-11,35e-11])
plt.title('Histogram hamaker')

plt.figure
plt.plot(hamaker)
#     # break
# df
# Out:
# length of hamaker : 690

# %%
# val = df['hamaker_values']
# val1 = list(val)
# val1
# len(hamaker)
# val[1:]
plt.figure
plt.plot(hamaker)
